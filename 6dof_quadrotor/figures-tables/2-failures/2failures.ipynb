# %%
import sys
import os
sys.path.insert(0, '../../')
import plots
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.lines as mlines

analyzer = plots.DataAnalyser()

# %%
plt.rcParams.update({'font.family': 'serif'})
plt.rcParams.update({'font.size': 13})
path = 'dataset_metadata_25-07-21.csv'
df_total = pd.read_csv(path, sep=',')

# %%
# Failed simulations - MPC
df_total.groupby('mpc_success').count()
# Out:
#              sim_id  trajectory_id  trajectory_type  disturbed_inputs  \
# mpc_success
# False            10             10               10                10
# True             18             18               18                18
#
#              simulation_time (s)  time_sample (s)   N   M  num_iterations  \
# mpc_success
# False                         10               10  10  10               0
# True                          18               18  18  18              18
#
#              mpc_RMSe  ...  period (s)  inter_position_RMSe  RMSe_u0  RMSe_u1  \
# mpc_success            ...
# False               0  ...           0                    0        0        0
# True               18  ...           0                   15       15       15
#
#              RMSe_u2  RMSe_u3  RMSe_u4  RMSe_u5  RMSe_u6  RMSe_u7
# mpc_success
# False              0        0        0        0        0        0
# True              15       15       15       15       15       15
#
# [2 rows x 69 columns]

# %%
# Failed simulations - NN
df_total.groupby('nn_success').count()
# Out:
#             sim_id  trajectory_id  trajectory_type  disturbed_inputs  \
# nn_success
# False           12             12               12                12
# True            16             16               16                16
#
#             simulation_time (s)  time_sample (s)   N   M  mpc_success  \
# nn_success
# False                        12               12  12  12           12
# True                         16               16  16  16           16
#
#             num_iterations  ...  period (s)  inter_position_RMSe  RMSe_u0  \
# nn_success                  ...
# False                    3  ...           0                    0        0
# True                    15  ...           0                   15       15
#
#             RMSe_u1  RMSe_u2  RMSe_u3  RMSe_u4  RMSe_u5  RMSe_u6  RMSe_u7
# nn_success
# False             0        0        0        0        0        0        0
# True             15       15       15       15       15       15       15
#
# [2 rows x 69 columns]

# %%
nn_success_df = df_total[df_total['nn_success'] == True]
nn_success_df['failed_rotors'] = nn_success_df['failed_rotors'].apply(lambda x: np.array([int(s) for s in x.split('-')]))

nn_failed_df = df_total[df_total['nn_success'] == False]
nn_failed_df['failed_rotors'] = nn_failed_df['failed_rotors'].apply(lambda x: [int(s) for s in x.split('-')])

mpc_success_df = df_total[df_total['mpc_success'] == True]
mpc_success_df['failed_rotors'] = mpc_success_df['failed_rotors'].apply(lambda x: np.array([int(s) for s in x.split('-')]))

mpc_failed_df = df_total[df_total['mpc_success'] == False]
mpc_failed_df['failed_rotors'] = mpc_failed_df['failed_rotors'].apply(lambda x: [int(s) for s in x.split('-')])

#mpc_success = np.concatenate(mpc_success_df['failed_rotors'].to_numpy(), axis = 0)
mpc_success = np.vstack(mpc_success_df['failed_rotors'])
mpc_failed = np.vstack(mpc_failed_df['failed_rotors'])

nn_success = np.vstack(nn_success_df['failed_rotors'])
nn_failed = np.vstack(nn_failed_df['failed_rotors'])

plots = [
    [mpc_success, mpc_failed],
    [nn_success, nn_failed]
]
# Out:
# C:\Users\mathe\AppData\Local\Temp\ipykernel_10320\3401443032.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nn_success_df['failed_rotors'] = nn_success_df['failed_rotors'].apply(lambda x: np.array([int(s) for s in x.split('-')]))
# C:\Users\mathe\AppData\Local\Temp\ipykernel_10320\3401443032.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nn_failed_df['failed_rotors'] = nn_failed_df['failed_rotors'].apply(lambda x: [int(s) for s in x.split('-')])
# C:\Users\mathe\AppData\Local\Temp\ipykernel_10320\3401443032.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mpc_success_df['failed_rotors'] = mpc_success_df['failed_rotors'].apply(lambda x: np.array([int(s) for s in x.split('-')]))
# C:\Users\mathe\AppData\Local\Temp\ipykernel_10320\3401443032.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mpc_failed_df['failed_rotors'] = mpc_failed_df['failed_rotors'].apply(lambda x: [int(s) for s in x.split('-')])

# %%
fig, axs = plt.subplots(1,2)
for i, ax in enumerate(axs.flatten()):
    plot = plots[i]
    ax.plot(plot[0][:,0], plot[0][:,1], 'og') # Success
    ax.plot(plot[1][:,0], plot[1][:,1], 'xr') # Failed
fig.tight_layout()

# %%
plot = []

for rotor_combination_mpc in mpc_success:
    both_success = False
    for rotor_combination_nn in nn_success:
        if rotor_combination_mpc[0] in rotor_combination_nn and rotor_combination_mpc[1] in rotor_combination_nn:
            both_success = True
            plot.append([rotor_combination_mpc[0], rotor_combination_mpc[1], 'o', 'green', 'MPC and NN Success'])
    if not both_success: # MPC success and NN fail
        plot.append([rotor_combination_mpc[0], rotor_combination_mpc[1], '+', 'blue', 'MPC Success and NN Fail'])

for rotor_combination_mpc in mpc_failed:
    both_failed = False
    for rotor_combination_nn in nn_failed:
        if rotor_combination_mpc[0] in rotor_combination_nn and rotor_combination_mpc[1] in rotor_combination_nn:
            both_failed = True
            plot.append([rotor_combination_mpc[0], rotor_combination_mpc[1], 'x', 'red', 'MPC and NN Fail'])
    if not both_failed: # MPC fail and NN success
        plot.append([rotor_combination_mpc[0], rotor_combination_mpc[1], '1', 'blue', 'MPC Fail and NN Success'])

labels = []
fig= plt.figure()
for i, p in enumerate(plot):
    if p[4] in labels:
        plt.plot(p[0]+1, p[1]+1, marker=p[2], color=p[3], markersize=11,linewidth=2, linestyle='None', markeredgewidth=2)
    else:
        plt.plot(p[0]+1, p[1]+1, marker=p[2], color=p[3], label=p[4], markersize=11,linewidth=2, linestyle='None',markeredgewidth=2)
        labels.append(p[4])
    plt.legend()
    plt.title('Successful and Failed MPC-NN Simulations with 2 Rotor Failures', fontsize=13)
    plt.xlabel('Failed Rotor 1')
    plt.ylabel('Failed Rotor 2')
    plt.grid(True)
    plt.tight_layout()
    fig.savefig('2rotor-distribution.pdf',bbox_inches='tight')
    #else:
    #    handles.append(plt.plot(p[0], p[1], marker=p[2], color=p[3],markersize=10,linewidth=2))

# %%
df_both_success = df_total[(df_total['nn_success'] == True) & (df_total['mpc_success'] == True)]
len(df_both_success)

analyzer.plot_histogram(df_both_success, 'mpc_RMSe', 'nn_RMSe', 'Trajectory RMSE (m)','MPC and NN Trajectory RMSE Distributions', ['MPC', 'Neural Network'], percentile_1=0.90, percentile_2=0.90, show_mean=False, num_bins=40, stat='count')
# Out:
# percentile 1 (0.9) = 7.7721735463301105
# percentile 2 (0.9) = 6.798128833370668

# %%
stats_rmse = analyzer.stats_simulations(df_both_success, 'mpc_RMSe', 'nn_RMSe')
stats_rmse
# Out:
#        Controller       min       max      mean       std
# 0             MPC  0.022234  7.772174  1.538467  3.017551
# 1  Neural Network  0.026527  6.798129  0.806880  1.886890

# %%
df_histogram = df_total[(df_total['nn_success'] == True) | (df_total['mpc_success'] == True)]
print(len(df_histogram))

analyzer.plot_histogram(df_histogram, 'mpc_RMSe', 'nn_RMSe', 'Trajectory RMSE (m)','MPC and NN Trajectory RMSE Distributions', ['MPC', 'Neural Network'], save_name='2rotorsfail_rmse.pdf', show_mean=False, num_bins=40, stat='count')
# Out:
# 19

# %%
analyzer.stats_simulations(df_histogram, 'mpc_RMSe', 'nn_RMSe')
# Out:
#        Controller       min        max      mean        std
# 0             MPC  0.022234  43.425493  6.128745  11.793960
# 1  Neural Network  0.026527   6.798129  1.017528   2.008222

# %%
fig = plt.figure()

df_histogram['nn_max_abs_phi'] = np.max(np.abs(df_histogram[['nn_max_phi (rad)','nn_min_phi (rad)']]), axis = 1)
df_histogram['mpc_max_abs_phi'] = np.max(np.abs(df_histogram[['mpc_max_phi (rad)','mpc_min_phi (rad)']]), axis = 1)
df_histogram['nn_max_abs_theta'] = np.max(np.abs(df_histogram[['nn_max_theta (rad)','nn_min_theta (rad)']]), axis = 1)
df_histogram['mpc_max_abs_theta'] = np.max(np.abs(df_histogram[['mpc_max_theta (rad)','mpc_min_theta (rad)']]), axis = 1)
df_histogram['nn_max_abs_psi'] = np.max(np.abs(df_histogram[['nn_max_psi (rad)','nn_min_psi (rad)']]), axis = 1)
df_histogram['mpc_max_abs_psi'] = np.max(np.abs(df_histogram[['mpc_max_psi (rad)','mpc_min_psi (rad)']]), axis = 1)

df_histogram['mpc_alpha'] = (df_histogram['mpc_max_abs_phi'] + df_histogram['mpc_max_abs_theta'] + df_histogram['mpc_max_abs_psi'])/3
df_histogram['nn_alpha'] = (df_histogram['nn_max_abs_phi'] + df_histogram['nn_max_abs_theta'] + df_histogram['nn_max_abs_psi'])/3

plt.scatter(df_histogram['mpc_alpha'], df_histogram['mpc_RMSe'])
plt.scatter(df_histogram['nn_alpha'], df_histogram['nn_RMSe'])
plt.xlabel('Alpha')
plt.ylabel('TRMSE')
# Out:
# C:\Users\mathe\AppData\Local\Temp\ipykernel_10320\3717561780.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_histogram['nn_max_abs_phi'] = np.max(np.abs(df_histogram[['nn_max_phi (rad)','nn_min_phi (rad)']]), axis = 1)
# C:\Users\mathe\AppData\Local\Temp\ipykernel_10320\3717561780.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_histogram['mpc_max_abs_phi'] = np.max(np.abs(df_histogram[['mpc_max_phi (rad)','mpc_min_phi (rad)']]), axis = 1)
# C:\Users\mathe\AppData\Local\Temp\ipykernel_10320\3717561780.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_histogram['nn_max_abs_theta'] = np.max(np.abs(df_histogram[['nn_max_theta (rad)','nn_min_theta (rad)']]), axis = 1)
# C:\Users\mathe\AppData\Local\Temp\ipykernel_10320\3717561780.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_histogram['mpc_max_abs_theta'] = np.max(np.abs(df_histogram[['mpc_max_theta (rad)','mpc_min_theta (rad)']]), axis = 1)
# C:\Users\mathe\AppData\Local\Temp\ipykernel_10320\3717561780.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_histogram['nn_max_abs_psi'] = np.max(np.abs(df_histogram[['nn_max_psi (rad)','nn_min_psi (rad)']]), axis = 1)
# C:\Users\mathe\AppData\Local\Temp\ipykernel_10320\3717561780.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_histogram['mpc_max_abs_psi'] = np.max(np.abs(df_histogram[['mpc_max_psi (rad)','mpc_min_psi (rad)']]), axis = 1)
# C:\Users\mathe\AppData\Local\Temp\ipykernel_10320\3717561780.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_histogram['mpc_alpha'] = (df_histogram['mpc_max_abs_phi'] + df_histogram['mpc_max_abs_theta'] + df_histogram['mpc_max_abs_psi'])/3
# C:\Users\mathe\AppData\Local\Temp\ipykernel_10320\3717561780.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_histogram['nn_alpha'] = (df_histogram['nn_max_abs_phi'] + df_histogram['nn_max_abs_theta'] + df_histogram['nn_max_abs_psi'])/3
# Text(0, 0.5, 'TRMSE')
